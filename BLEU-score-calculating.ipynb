# %%
import pandas as pd

# df = pd.read_csv("translation_result.csv")
df = pd.read_csv("translation_result_of_nllb-200-1.3B_zh2ja_0907.csv")
df["candidates"] = df["candidates"].fillna(value="<pad>")
df
# Out:
#             source               references             candidates
# 0             （觉醒）                     （覚醒）                  (目覚め)
# 1               一般                        俗                     一般
# 2              （大）                      （大）                    (大)
# 3          （出现在）视野                 視界（に浮かぶ）                 (出現)視野
# 4              （中）                      （中）                    (中)
# ...            ...                      ...                    ...
# 10856   装备附魔槽位已到上限  装備のインチャントスロットがすでにいっぱいです  装備のスペシャルスロットの上限に達しました
# 10857  该装备不能使用此魔力石           魔力石が使用できない装備です           この装備は使用できません
# 10858       角色已经死亡             キャラクターが死にました               キャラクター死亡
# 10859      服务器战斗出错               サーバーデータエラー             サーバーバトルエラー
# 10860       功能暂未开放               この機能は未開放です           この機能はまだ未開放です
#
# [10861 rows x 3 columns]

# %%
# references = df["references"].to_list()
references = [[reference] for reference in df["references"].to_list()]
candidates = df["candidates"].to_list()

# %%
from nltk.translate.bleu_score import corpus_bleu

score = corpus_bleu(references, candidates)
score
# Out:
# 0.7323997058282252
